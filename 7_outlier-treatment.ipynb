# %% [markdown]
# ## Outlier treatment

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('gurgaon_properties_cleaned_v2.csv').drop_duplicates()

# %%
df.head()
# Out:
#   property_type             society     sector  price  price_per_sqft    area  \
# 0          flat  umang winter hills  sector 77   0.86          6408.0  1342.0
# 1          flat      pivotal devaan  sector 84   0.41          7032.0   583.0
# 2         house      dlf city plots  sector 26  17.30         38734.0  4466.0
# 3         house       sector 38 rwa  sector 38   4.30         28782.0  1494.0
# 4         house         independent  sector 92   1.80          7627.0  2360.0
#
#                                         areaWithType  bedRoom  bathroom  \
# 0             Super Built up area 1342(124.68 sq.m.)        2         2
# 1  Super Built up area 583(54.16 sq.m.)Built Up a...        2         2
# 2                        Plot area 502(419.74 sq.m.)        6         7
# 3  Plot area 166(138.8 sq.m.)Built Up area: 165 s...        9         9
# 4                 Built Up area: 2360 (219.25 sq.m.)        4         5
#
# ...

# %%
df.shape
# Out:
# (3677, 23)

# %%
df.columns
# Out:
# Index(['property_type', 'society', 'sector', 'price', 'price_per_sqft', 'area',
#        'areaWithType', 'bedRoom', 'bathroom', 'balcony', 'floorNum', 'facing',
#        'agePossession', 'super_built_up_area', 'built_up_area', 'carpet_area',
#        'study room', 'servant room', 'store room', 'pooja room', 'others',
#        'furnishing_type', 'luxury_score'],
#       dtype='object')

# %%
# outliers on the basis of price column
sns.distplot(df['price'])
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_19896\2797181776.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['price'])
# c:\Users\User\anaconda3\envs\Research_env\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='price', ylabel='Density'>

# %%
sns.boxplot(x=df['price'])
# values lesser than lower_bound and greater than upper_bound are outliers
# Out:
# <Axes: xlabel='price'>

# %%
# Calculate the IQR for the 'price' column
Q1 = df['price'].quantile(0.25)
Q3 = df['price'].quantile(0.75)
IQR = Q3 - Q1

# Define bounds for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Identify outliers
outliers = df[(df['price'] < lower_bound) | (df['price'] > upper_bound)]

# Displaying the number of outliers and some statistics
num_outliers = outliers.shape[0]
outliers_price_stats = outliers['price'].describe()

num_outliers, outliers_price_stats
# Extracting all rows which are considered outliers -> then find the statistical values
# Out:
# (425,
#  count    425.000000
#  mean       9.235624
#  std        4.065259
#  min        5.460000
#  25%        6.460000
#  50%        8.000000
#  75%       10.750000
#  max       31.500000
#  Name: price, dtype: float64)

# %%
outliers.sort_values('price',ascending=False).head(20)
# Out:
#      property_type                                            society  \
# 576          house  arjun marg/ sector- 26 phase- 1/ golf course road
# 1574         house                                        independent
# 1962         house                                        independent
# 3292         house                                     dlf city plots
# 1715         house                                   suncity township
# 755          house                             emaar the palm springs
# 945          house                                        independent
# 2912         house                                 vipul tatvam villa
# 2204         house                                     dlf city plots
# 3252         house                                        independent
# 1180         house                             luxury dlf city floors
# 667          house                                        independent
# ...

# %% [markdown]
# ### Analysing by exporting it to a excel file
#     some property are really very expensive
#     on the basis of price col we can say that there are some genuine outliers but there are some data erros as well

# %% [markdown]
# ### Price_per_sqft

# %%
sns.distplot(df['price_per_sqft'])
# heavily right skewed
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_19896\3466941862.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['price_per_sqft'])
# c:\Users\User\anaconda3\envs\Research_env\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='price_per_sqft', ylabel='Density'>

# %%
sns.boxplot(x=df['price_per_sqft'])
# Out:
# <Axes: xlabel='price_per_sqft'>

# %%
# Calculate the IQR for the 'price' column
Q1 = df['price_per_sqft'].quantile(0.25)
Q3 = df['price_per_sqft'].quantile(0.75)
IQR = Q3 - Q1

# Define bounds for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Identify outliers
outliers_sqft = df[(df['price_per_sqft'] < lower_bound) | (df['price_per_sqft'] > upper_bound)]

# Displaying the number of outliers and some statistics
num_outliers = outliers_sqft.shape[0]
outliers_sqft_stats = outliers_sqft['price_per_sqft'].describe()

num_outliers, outliers_sqft_stats
# 354 outliers
# Out:
# (354,
#  count       354.000000
#  mean      52592.612994
#  std       61150.458507
#  min       24489.000000
#  25%       28208.250000
#  50%       33368.500000
#  75%       41982.250000
#  max      600000.000000
#  Name: price_per_sqft, dtype: float64)

# %% [markdown]
# ###
#     There is a data error found while converting the units of area

# %%
outliers_sqft['area'] = outliers_sqft['area'].apply(lambda x:x*9 if x<1000 else x)
# converting sqft to sqm for area less than 1000 only for outliers
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_19896\658394882.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   outliers_sqft['area'] = outliers_sqft['area'].apply(lambda x:x*9 if x<1000 else x)

# %%
outliers_sqft['price_per_sqft'] = round((outliers_sqft['price']*10000000)/outliers_sqft['area'])
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_19896\2491436972.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   outliers_sqft['price_per_sqft'] = round((outliers_sqft['price']*10000000)/outliers_sqft['area'])

# %%
outliers_sqft['price_per_sqft'].describe()
# Out:
# count      354.000000
# mean     29357.906780
# std      12403.077309
# min       2723.000000
# 25%      25562.000000
# 50%      29870.500000
# 75%      35549.500000
# max      82540.000000
# Name: price_per_sqft, dtype: float64

# %%
df.update(outliers_sqft)

# %%
sns.distplot(df['price_per_sqft'])
# improved distribution
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_19896\3877531323.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['price_per_sqft'])
# c:\Users\User\anaconda3\envs\Research_env\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='price_per_sqft', ylabel='Density'>

# %%
sns.boxplot(x=df['price_per_sqft'])
# Out:
# <Axes: xlabel='price_per_sqft'>

# %%
df[df['price_per_sqft']>50000]
#just dropping the rows with price_per_sqft greater than 50000 from the dataset
# Out:
#      property_type                       society           sector  price  \
# 16           house                   independent        sector 25  16.00
# 293           flat                unitech vistas        sector 70   9.00
# 755          house        emaar the palm springs        sector 54  24.00
# 868          house                   independent        sector 26  14.75
# 1962         house                   independent        sector 26  26.00
# 2529         house                unitech escape        sector 50  10.80
# 2601         house  project housing board colony        sector 31   8.00
# 2771         house            emaar mgf marbella        sector 66  18.00
# 3292         house                dlf city plots        sector 26  26.00
# 3406         house                           nul        sector 28  12.50
# 3418         house                  malibu towne        sector 47   8.50
# 3768         house        emaar the palm springs        sector 54  14.00
# ...

# %%
df = df[df['price_per_sqft'] <= 50000]

# %%
sns.boxplot(x=df['price_per_sqft'])
# Out:
# <Axes: xlabel='price_per_sqft'>

# %% [markdown]
# ### Area

# %%
sns.distplot(df['area'])
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_19896\91062565.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['area'])
# c:\Users\User\anaconda3\envs\Research_env\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='area', ylabel='Density'>

# %%
sns.boxplot(x=df['area'])
# Out:
# <Axes: xlabel='area'>

# %%
df['area'].describe()
# Out:
# count      3647.000000
# mean       2947.723608
# std       23208.194102
# min         145.000000
# 25%        1262.000000
# 50%        1750.000000
# 75%        2350.000000
# max      875000.000000
# Name: area, dtype: float64

# %%
df[df['area'] > 100000]
# Out:
#      property_type                    society      sector  price  \
# 135           flat  signature global solera 2  sector 107   0.51
# 679           flat      signature the roselia   sector 95   0.45
# 1901         house                independent   sector 50   5.00
# 3413          flat          hcbs sports ville  sohna road   0.35
# 3604          flat            ramsons kshitij   sector 95   0.31
#
#       price_per_sqft      area                           areaWithType  \
# 135              9.0  566667.0   Carpet area: 514396 (47788.95 sq.m.)
# 679              7.0  642857.0   Carpet area: 569243 (52884.41 sq.m.)
# 1901           232.0  215517.0             Plot area 2(1011.71 sq.m.)
# 3413             4.0  875000.0  Built Up area: 737147 (68483.2 sq.m.)
# 3604             5.0  620000.0    Carpet area: 607936 (56479.1 sq.m.)
#
#       bedRoom  bathroom balcony  floorNum      facing   agePossession  \
# 135         2         2       1       3.0       North    New Property
# ...

# %%
# just drooping the rows with area greater than 100000 from the dataset. since prices are very less but area is very large
df = df[df['area'] < 100000]

# %%
sns.distplot(df['area'])
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_19896\91062565.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['area'])
# c:\Users\User\anaconda3\envs\Research_env\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='area', ylabel='Density'>

# %%
sns.boxplot(x=df['area'])
# Out:
# <Axes: xlabel='area'>

# %%
df[df['area'] > 10000].sort_values('area',ascending=False)
# Finding areas over 100000
# 1360, 2347, 2002, 2367, 3772, 3507, 3011, 3404, 740
# Out:
#      property_type                    society           sector  price  \
# 1360         house                independent        sector 26  18.40
# 435          house  ganpati heights apartment        sector 13   1.25
# 2347          flat                 rof ananda        sector 95   0.38
# 2002          flat                 rof ananda        sector 95   0.38
# 2909         house      dlf city plot phase 4        sector 28  13.00
# 2367          flat              pyramid elite        sector 86   0.46
# 3772          flat                 rof ananda        sector 95   0.33
# 3507          flat      signature the serenas       sohna road   0.28
# 39           house                independent        sector 25   7.30
# 3011          flat            ramsons kshitij        sector 95   0.24
# 3404          flat                 rof ananda        sector 95   0.21
# 274          house                independent        sector 57   6.25
# ...

# %%
# Since these rows have error in the data entry so dropping them
df.drop(index=[1360, 2347, 2002, 2367, 3772, 3507, 3011, 3404, 740], inplace=True)

# %%
df[df['area'] > 10000].sort_values('area',ascending=False)
# Out:
#      property_type                    society           sector  price  \
# 435          house  ganpati heights apartment        sector 13   1.25
# 2909         house      dlf city plot phase 4        sector 28  13.00
# 39           house                independent        sector 25   7.30
# 274          house                independent        sector 57   6.25
# 1127         house                independent        sector 43   5.50
# 3699          flat                 godrej air        sector 85   2.50
# 337          house       unitech aspen greens        sector 50   6.95
# 3470          flat                godrej icon       sector 88a   1.75
# 1574         house                independent        sector 43  27.50
# 3293          flat             m3m golfestate        sector 65  13.20
# 594          house                independent  sohna road road   5.50
#
#       price_per_sqft     area  \
# 435            151.0  82781.0
# 2909          1992.0  65261.0
# 39            1560.0  46795.0
# ...

# %%
df[df['area'] > 10000].sort_values('area',ascending=False)
# Out:
#      property_type                    society           sector  price  \
# 435          house  ganpati heights apartment        sector 13   1.25
# 2909         house      dlf city plot phase 4        sector 28  13.00
# 39           house                independent        sector 25   7.30
# 274          house                independent        sector 57   6.25
# 1127         house                independent        sector 43   5.50
# 3699          flat                 godrej air        sector 85   2.50
# 337          house       unitech aspen greens        sector 50   6.95
# 3470          flat                godrej icon       sector 88a   1.75
# 1574         house                independent        sector 43  27.50
# 3293          flat             m3m golfestate        sector 65  13.20
# 594          house                independent  sohna road road   5.50
#
#       price_per_sqft     area  \
# 435            151.0  82781.0
# 2909          1992.0  65261.0
# 39            1560.0  46795.0
# ...

# %%
# for some rows using the carpet area and built up are to update the actual area
df.loc[435,'area'] = 115*9
df.loc[2909,'area'] = 7250
df.loc[39,'area'] = 5800
df.loc[274,'area'] = 2660
df.loc[1127,'area'] = 2850
df.loc[3699,'area'] = 1812
df.loc[337,'area'] = 2160
df.loc[3470,'area'] = 1175

# %%
sns.distplot(df['area'])
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_19896\91062565.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['area'])
# c:\Users\User\anaconda3\envs\Research_env\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='area', ylabel='Density'>

# %%
sns.boxplot(x=df['area'])
# Out:
# <Axes: xlabel='area'>

# %%
df['area'].describe()
# Out:
# count     3633.000000
# mean      1950.357005
# std       1215.707897
# min        145.000000
# 25%       1260.000000
# 50%       1747.000000
# 75%       2325.000000
# max      11286.000000
# Name: area, dtype: float64

# %% [markdown]
# ### Bedroom

# %%
sns.distplot(df['bedRoom'])
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_19896\1691983684.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['bedRoom'])
# c:\Users\User\anaconda3\envs\Research_env\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='bedRoom', ylabel='Density'>

# %%
sns.boxplot(x=df['bedRoom'])
# Out:
# <Axes: xlabel='bedRoom'>

# %%
df['bedRoom'].describe()
# Out:
# count    3633.000000
# mean        3.333609
# std         1.830035
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         4.000000
# max        21.000000
# Name: bedRoom, dtype: float64

# %%
df[df['bedRoom'] > 10].sort_values('bedRoom',ascending=False)
# Out:
#      property_type                      society      sector  price  \
# 2135         house                  independent   sector 54   5.00
# 246          house                  independent   sector 43   4.50
# 2300         house                  independent  sector 17a   3.87
# 3527         house                  independent  sector 17a   3.93
# 2433         house                  independent   sector 54   5.50
# 3019         house                private house   sector 55   7.05
# 2441         house                  independent   sector 56  12.39
# 692          house                  independent   sector 55   9.19
# 2204         house               dlf city plots   sector 26  20.00
# 1960         house                  independent   sector 43  13.50
# 2930         house                  independent   sector 40  12.00
# 2972         house                  independent   sector 11   4.50
# 1180         house       luxury dlf city floors   sector 26  20.00
# ...

# %%
df = df[df['bedRoom'] <= 10]

# %%
df.shape
# Out:
# (3588, 23)

# %%
sns.distplot(df['bedRoom'])
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_19896\1691983684.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['bedRoom'])
# c:\Users\User\anaconda3\envs\Research_env\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='bedRoom', ylabel='Density'>

# %%
sns.boxplot(x=df['bedRoom'])
# Out:
# <Axes: xlabel='bedRoom'>

# %%
df['bedRoom'].describe()
# Out:
# count    3588.000000
# mean        3.203735
# std         1.393968
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         4.000000
# max        10.000000
# Name: bedRoom, dtype: float64

# %% [markdown]
# ### Bathroom

# %%
sns.distplot(df['bathroom'])
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_19896\2904465235.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['bathroom'])
# c:\Users\User\anaconda3\envs\Research_env\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='bathroom', ylabel='Density'>

# %%
sns.boxplot(x=df['bathroom'])
# Out:
# <Axes: xlabel='bathroom'>

# %%
df[df['bathroom'] > 10].sort_values('bathroom',ascending=False)
# Out:
#      property_type               society     sector  price  price_per_sqft  \
# 761          house  adani brahma samsara  sector 60  18.02         28200.0
# 501          house           independent  sector 39   7.00         10000.0
# 3499         house           independent  sector 24  11.00         28902.0
#
#         area                                       areaWithType  bedRoom  \
# 761   6390.0                 Built Up area: 6390 (593.65 sq.m.)        9
# 501   7000.0  Plot area 350(32.52 sq.m.)Built Up area: 7000 ...       10
# 3499  3806.0  Plot area 3806.45(353.63 sq.m.)Built Up area: ...        8
#
#       bathroom balcony  floorNum      facing   agePossession  \
# 761         12      3+       3.0  North-East  Relatively New
# 501         11      3+       4.0  South-East  Relatively New
# 3499        11      3+       3.0        East    Old Property
#
#       super_built_up_area  built_up_area  carpet_area  study room  \
# ...

# %%
df.head()
# Out:
#   property_type             society     sector  price  price_per_sqft    area  \
# 0          flat  umang winter hills  sector 77   0.86          6408.0  1342.0
# 1          flat      pivotal devaan  sector 84   0.41          7032.0   583.0
# 2         house      dlf city plots  sector 26  17.30         38737.0  4466.0
# 3         house       sector 38 rwa  sector 38   4.30         28782.0  1494.0
# 4         house         independent  sector 92   1.80          7627.0  2360.0
#
#                                         areaWithType  bedRoom  bathroom  \
# 0             Super Built up area 1342(124.68 sq.m.)        2         2
# 1  Super Built up area 583(54.16 sq.m.)Built Up a...        2         2
# 2                        Plot area 502(419.74 sq.m.)        6         7
# 3  Plot area 166(138.8 sq.m.)Built Up area: 165 s...        9         9
# 4                 Built Up area: 2360 (219.25 sq.m.)        4         5
#
# ...

# %% [markdown]
# ### super built up area

# %%
sns.distplot(df['super_built_up_area'])
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_19896\4184943455.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['super_built_up_area'])
# c:\Users\User\anaconda3\envs\Research_env\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='super_built_up_area', ylabel='Density'>

# %%
sns.boxplot(x=df['super_built_up_area'])
# Out:
# <Axes: xlabel='super_built_up_area'>

# %%
df['super_built_up_area'].describe()
# Out:
# count     1875.000000
# mean      1925.237627
# std        764.172177
# min         89.000000
# 25%       1479.500000
# 50%       1828.000000
# 75%       2215.000000
# max      10000.000000
# Name: super_built_up_area, dtype: float64

# %%
df[df['super_built_up_area'] > 6000]
# Out:
#      property_type                      society       sector  price  \
# 127           flat       krrish provence estate  gwal pahari    7.5
# 2174          flat  bestech park view grand spa    sector 81    4.7
#
#       price_per_sqft     area                             areaWithType  \
# 127           7500.0  10000.0  Super Built up area 10000(929.03 sq.m.)
# 2174          6786.0   6926.0   Super Built up area 6926(643.45 sq.m.)
#
#       bedRoom  bathroom balcony  floorNum      facing   agePossession  \
# 127         5         6      3+      23.0  North-East  Relatively New
# 2174        4         4      3+      19.0       North  Relatively New
#
#       super_built_up_area  built_up_area  carpet_area  study room  \
# 127               10000.0            NaN          NaN           0
# 2174               6926.0            NaN          NaN           0
#
#       servant room  store room  pooja room  others  furnishing_type  \
# ...

# %% [markdown]
# ### built up area

# %%
sns.distplot(df['built_up_area'])
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_19896\3494228458.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['built_up_area'])
# c:\Users\User\anaconda3\envs\Research_env\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='built_up_area', ylabel='Density'>

# %%
sns.boxplot(x=df['built_up_area'])
# Out:
# <Axes: xlabel='built_up_area'>

# %%
df[df['built_up_area'] > 10000]
# Out:
#      property_type      society     sector  price  price_per_sqft     area  \
# 1574         house  independent  sector 43   27.5         24366.0  11286.0
#
#                       areaWithType  bedRoom  bathroom balcony  floorNum  \
# 1574  Plot area 1254(1048.5 sq.m.)        6         7      3+       3.0
#
#           facing   agePossession  super_built_up_area  built_up_area  \
# 1574  North-East  Relatively New                  NaN        11286.0
#
#       carpet_area  study room  servant room  store room  pooja room  others  \
# 1574          NaN           1             1           0           1       1
#
#       furnishing_type  luxury_score
# 1574                1            42

# %% [markdown]
# ### carpet area

# %%
sns.distplot(df['carpet_area'])
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_19896\3905767603.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['carpet_area'])
# c:\Users\User\anaconda3\envs\Research_env\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='carpet_area', ylabel='Density'>

# %%
sns.boxplot(x=df['carpet_area'])
# Out:
# <Axes: xlabel='carpet_area'>

# %%
df[df['carpet_area'] > 10000]
# Out:
#      property_type         society     sector  price  price_per_sqft     area  \
# 3293          flat  m3m golfestate  sector 65   13.2         12000.0  11000.0
# 3699          flat      godrej air  sector 85    2.5          1379.0   1812.0
#
#                             areaWithType  bedRoom  bathroom balcony  floorNum  \
# 3293  Carpet area: 11000 (1021.93 sq.m.)        4         4       3      13.0
# 3699  Carpet area: 18122 (1683.59 sq.m.)        4         5      3+      16.0
#
#           facing       agePossession  super_built_up_area  built_up_area  \
# 3293       North      Moderately Old                  NaN            NaN
# 3699  North-East  Under Construction                  NaN            NaN
#
#       carpet_area  study room  servant room  store room  pooja room  others  \
# 3293      11000.0           0             1           0           0       0
# 3699      18122.0           1             0           0           1       1
#
#       furnishing_type  luxury_score
# ...

# %%
df.loc[3699,'carpet_area'] = 1812

# %%
df[df['carpet_area'] > 10000]
# Out:
#      property_type         society     sector  price  price_per_sqft     area  \
# 3293          flat  m3m golfestate  sector 65   13.2         12000.0  11000.0
#
#                             areaWithType  bedRoom  bathroom balcony  floorNum  \
# 3293  Carpet area: 11000 (1021.93 sq.m.)        4         4       3      13.0
#
#      facing   agePossession  super_built_up_area  built_up_area  carpet_area  \
# 3293  North  Moderately Old                  NaN            NaN      11000.0
#
#       study room  servant room  store room  pooja room  others  \
# 3293           0             1           0           0       0
#
#       furnishing_type  luxury_score
# 3293                2            60

# %%
df.head()
# Out:
#   property_type             society     sector  price  price_per_sqft    area  \
# 0          flat  umang winter hills  sector 77   0.86          6408.0  1342.0
# 1          flat      pivotal devaan  sector 84   0.41          7032.0   583.0
# 2         house      dlf city plots  sector 26  17.30         38737.0  4466.0
# 3         house       sector 38 rwa  sector 38   4.30         28782.0  1494.0
# 4         house         independent  sector 92   1.80          7627.0  2360.0
#
#                                         areaWithType  bedRoom  bathroom  \
# 0             Super Built up area 1342(124.68 sq.m.)        2         2
# 1  Super Built up area 583(54.16 sq.m.)Built Up a...        2         2
# 2                        Plot area 502(419.74 sq.m.)        6         7
# 3  Plot area 166(138.8 sq.m.)Built Up area: 165 s...        9         9
# 4                 Built Up area: 2360 (219.25 sq.m.)        4         5
#
# ...

# %%
sns.distplot(df['luxury_score'])
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_19896\3385064764.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['luxury_score'])
# c:\Users\User\anaconda3\envs\Research_env\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='luxury_score', ylabel='Density'>

# %%
sns.boxplot(df['luxury_score'])
# no outliers
# Out:
# <Axes: >

# %%
df.shape
# Out:
# (3588, 23)

# %%
df['price_per_sqft'] = round((df['price']*10000000)/df['area'])

# %%
df.head()
# Out:
#   property_type             society     sector  price  price_per_sqft    area  \
# 0          flat  umang winter hills  sector 77   0.86          6408.0  1342.0
# 1          flat      pivotal devaan  sector 84   0.41          7033.0   583.0
# 2         house      dlf city plots  sector 26  17.30         38737.0  4466.0
# 3         house       sector 38 rwa  sector 38   4.30         28782.0  1494.0
# 4         house         independent  sector 92   1.80          7627.0  2360.0
#
#                                         areaWithType  bedRoom  bathroom  \
# 0             Super Built up area 1342(124.68 sq.m.)        2         2
# 1  Super Built up area 583(54.16 sq.m.)Built Up a...        2         2
# 2                        Plot area 502(419.74 sq.m.)        6         7
# 3  Plot area 166(138.8 sq.m.)Built Up area: 165 s...        9         9
# 4                 Built Up area: 2360 (219.25 sq.m.)        4         5
#
# ...

# %%
sns.distplot(df['price_per_sqft'])
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_19896\2186227091.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['price_per_sqft'])
# c:\Users\User\anaconda3\envs\Research_env\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='price_per_sqft', ylabel='Density'>

# %%
sns.boxplot(df['price_per_sqft'])
# Out:
# <Axes: >

# %%
df[df['price_per_sqft'] > 42000] # just few properties above 42000
# Out:
#      property_type                       society      sector  price  \
# 1148         house                   independent   sector 55    5.0
# 1155         house  sushant lok 1 builder floors   sector 43   13.0
# 1363         house                   independent   sector 43    9.5
# 2241         house                   independent  sector 105    9.9
# 2498         house                   independent   sector 25   13.0
# 2770         house                   independent   sector 26   19.0
# 3179         house                   independent   sector 28   12.0
# 3252         house                   independent   sector 26   20.0
# 3311         house                dlf city plots   sector 26   19.0
#
#       price_per_sqft    area  \
# 1148         44444.0  1125.0
# 1155         48148.0  2700.0
# 1363         42222.0  2250.0
# 2241         49500.0  2000.0
# 2498         45710.0  2844.0
# 2770         42222.0  4500.0
# 3179         42194.0  2844.0
# 3252         44444.0  4500.0
# ...

# %%
# comparing area and bedroom-> these could be outliers
x = df[df['price_per_sqft'] <= 20000]
(x['area']/x['bedRoom']).quantile(0.05) # area bedroom ratio -> this means only 2% of the data has this ratio.
# Out:
# 250.5

# %%
df[(df['area']/df['bedRoom'])<250]
# Out:
#      property_type                     society      sector  price  \
# 3            house               sector 38 rwa   sector 38   4.30
# 79            flat  central park flower valley   sector 33   1.40
# 113           flat                  rof ananda   sector 95   0.55
# 133           flat               gls avenue 51   sector 92   0.39
# 136          house                 independent   sector 47   4.30
# ...            ...                         ...         ...    ...
# 3680         house                 independent  sector 105   0.38
# 3718         house                 independent    sector 4   0.47
# 3727         house                 independent    sector 6   0.66
# 3753          flat     signature global solera  sector 107   0.50
# 3797         house                 independent    sector 2   3.65
#
#       price_per_sqft    area  \
# 3            28782.0  1494.0
# 79           21538.0   650.0
# 113           8527.0   645.0
# 133           6075.0   642.0
# ...

# %%
df[df['area']/df['bedRoom'] < 250].sample(5)
# these values doesn't seem to be correct as per the ratio. 
# But there could be possibility that houses could be multi storeyed
# Out:
#      property_type                   society      sector  price  \
# 1903         house               independent    sector 8   0.32
# 1665         house        sai kripa floors 5   sector 11   0.90
# 2946          flat             gls avenue 51   sector 92   0.50
# 3068          flat  breez global heights 88a  sector 88a   0.50
# 883          house               independent    sector 9   0.42
#
#       price_per_sqft   area  \
# 1903          7111.0  450.0
# 1665         11250.0  800.0
# 2946          7812.0  640.0
# 3068          8375.0  597.0
# 883           9333.0  450.0
#
#                                            areaWithType  bedRoom  bathroom  \
# 1903  Built Up area: 450 (41.81 sq.m.)Carpet area: 3...        2         3
# 1665                         Plot area 800(74.32 sq.m.)        5         5
# 2946               Super Built up area 640(59.46 sq.m.)        3         3
# 3068                     Carpet area: 597 (55.46 sq.m.)        3         2
# ...

# %%
sns.lmplot(data=df, x='area', y='bedRoom')
# Out:
# c:\Users\User\anaconda3\envs\Research_env\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
df['area_room_ratio'] = df['area']/df['bedRoom']

# %%
(df[df['area_room_ratio']<250])['bedRoom'].value_counts()
# Out:
# bedRoom
# 2     47
# 3     33
# 5     28
# 6     17
# 4     17
# 9     15
# 8     12
# 7      8
# 10     8
# Name: count, dtype: int64

# %%
df = df[df['area_room_ratio'] > 100]

# %%
outliers_df = df[(df['area_room_ratio'] < 250) & (df['bedRoom'] > 3)]
# doing these transformation due to multi storeyed houses

# %%
outliers_df['bedRoom'] = round(outliers_df['bedRoom']/outliers_df['floorNum'])
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_19896\3450078040.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   outliers_df['bedRoom'] = round(outliers_df['bedRoom']/outliers_df['floorNum'])

# %%
df.update(outliers_df)

# %%
df['area_room_ratio'] = df['area']/df['bedRoom']

# %%
df[(df['area_room_ratio'] < 250) & (df['bedRoom'] > 4)]
# Out:
#      property_type               society            sector  price  \
# 771          house           independent         sector 12   2.50
# 1382         house  bhim nagar, sector 6          sector 6   0.85
# 1681         house           independent         sector 11   3.50
# 1714         house           independent  sector 3 phase 2   0.85
# 1782         house           independent          sector 7   1.16
# 1822         house           independent  sector 3 phase 2   1.10
# 2146         house           independent           manesar   0.80
# 2158         house           independent           manesar   1.10
# 2213         house           independent          sector 2   0.98
# 3055         house           independent        sector 105   1.10
# 3350         house           independent         sector 17   0.32
# 3427         house              shivpuri          sector 7   2.80
# 3656         house           independent         sector 12   0.65
#
#       price_per_sqft    area  \
# ...

# %%
df[(df['area_room_ratio'] < 250) & (df['bedRoom'] > 4)].shape
# Out:
# (13, 24)

# %%
df.shape
# Out:
# (3568, 24)

# %%
df = df[~((df['area_room_ratio'] < 250) & (df['bedRoom'] > 4))]

# %%
sns.lmplot(data=df, x='area', y='bedRoom')
# Out:
# c:\Users\User\anaconda3\envs\Research_env\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
df.to_csv('gurgaon_properties_outlier_treated.csv',index=False)
